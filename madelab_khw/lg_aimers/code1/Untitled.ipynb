# %%
import pandas as pd
import os

if os.path.exists('/root/Public_Storage/madelab_khw/lg_aimers/dataset/train.csv'):
    df = pd.read_csv('/root/Public_Storage/madelab_khw/lg_aimers/dataset/test.csv')
else:
    print('none')

os.system('nvidia-smi')

num_1 = 0
num_0 = 0

for col in df['임신 성공 여부']:
    if col == 1:
        num_1+=1
    else:
        num0_0+=1
print(f'{num_0})
