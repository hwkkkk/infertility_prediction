# %%
import pandas as pd

test_path = "/root/Public_Storage/madelab_khw/lg_aimers/dataset/train.csv"
df = pd.read_csv(test_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 test_path = "/root/Public_Storage/madelab_khw/lg_aimers/dataset/train.csv"
# ----> 2 df = pd.read_csv(test_path)
#
# NameError: name 'pd' is not defined
